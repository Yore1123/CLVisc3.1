# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#sns.set_context("poster",font_scale=1.4)
#sns.despine()

# %%
dat = np.loadtxt("rhoB_baryon_init.dat")
dat1 = np.loadtxt("rhoB_baryon_t2.dat")
dat2 = np.loadtxt("rhoB_baryon_t5.dat")
dat3 = np.loadtxt("rhoB_baryon_t10.dat")
dat4 = np.loadtxt("rhoB_baryon_t20.dat")

dat5 = np.loadtxt("bulk3D_nb.dat")
u0 = 1.0/np.sqrt(1.0 - dat5[:,8]**2- dat5[:,9]**2- dat5[:,10]**2)
u3 = dat5[:,10]/np.sqrt(1.0 - dat5[:,8]**2- dat5[:,9]**2- dat5[:,10]**2)
qtau = np.loadtxt("qbtau_eta.dat")

# %%
music1 = np.loadtxt("1+1D_check_tau_1.02.dat")
music2 = np.loadtxt("1+1D_check_tau_2.dat")
music5 = np.loadtxt("1+1D_check_tau_5.dat")
music10 = np.loadtxt("1+1D_check_tau_10.dat")
music20 = np.loadtxt("1+1D_check_tau_20.dat")

# %%
plt.figure(figsize=(12,10))
# plt.plot(dat[:,0],dat[:,1],label = "1+1D Monnai",linewidth=3)
# plt.plot(dat1[:,0],dat1[:,1],linewidth=3)
# plt.plot(dat2[:,0],dat2[:,1],linewidth=3)
# plt.plot(dat3[:,0],dat3[:,1],linewidth=3)
# plt.plot(dat4[:,0],dat4[:,1],linewidth=3)


#plt.plot(music1[:,0],music1[:,2],label = "MUSIC",linewidth=3)
#plt.plot(music2[:,0],music2[:,5],linewidth=3,)
#plt.plot(music5[:,0],music5[:,5],linewidth=3)
plt.plot(music1[:,0],music1[:,7],linewidth=3)
#plt.plot(music10[:,0],music10[:,5],linewidth=3)
#plt.plot(music20[:,0],music20[:,2],linewidth=3)


#plt.scatter(dat5[np.fabs(dat5[:,0]-1.0)<0.0001,3][0:-1:20],dat5[np.fabs(dat5[:,0]-1.0)<0.0001,5][0:-1:20],label='Clvisc',s=80)
#plt.scatter(dat5[np.fabs(dat5[:,0]-2.0)<0.0001,3][0:-1:20],dat5[np.fabs(dat5[:,0]-2.0)<0.0001,5][0:-1:20],s=80)
#plt.scatter(dat5[np.fabs(dat5[:,0]-5.0)<0.0001,3],dat5[np.fabs(dat5[:,0]-5.0)<0.0001,-1],s=80)
#plt.plot(dat5[np.fabs(dat5[:,0]-5.0)<0.0001,3],qtau[np.fabs(dat5[:,0]-5.0)<0.0001])
plt.plot(dat5[np.fabs(dat5[:,0]-1.02)<0.0001,3],u0[np.fabs(dat5[:,0]-1.02)<0.0001])
#plt.plot(dat5[np.fabs(dat5[:,0]-20.0)<0.0001,3],qtau[np.fabs(dat5[:,0]-20.0)<0.0001])
#plt.scatter(dat5[np.fabs(dat5[:,0]-20.0)<0.0001,3],dat5[np.fabs(dat5[:,0]-20.0)<0.0001,5],s=80)


#plt.scatter(dat5[np.fabs(dat5[:,0]-20.0)<0.0001,3],dat5[np.fabs(dat5[:,0]-20.0)<0.0001,5],s=1)

print (np.max(qtau[np.fabs(dat5[:,0]-10.0)<0.0001]))
print (np.max(qtau[np.fabs(dat5[:,0]-20.0)<0.0001]))

#print (np.min(dat6[:,5]))
#plt.yscale('log')
#plt.xlim(-6.5,6.5)
plt.xlabel("$\eta$")
plt.ylabel("$nb(fm^{-3})$")
#plt.ylim(1e-7,1e0)
#plt.plot(dat5[np.fabs(dat5[:,0]-20.0)<0.0001,3],(qtau[np.fabs(dat5[:,0]-20.0)<0.0001]),label='clvisc')
#plt.plot(dat5[np.fabs(dat5[:,0]-2.1)<0.0001,3],(qtau[np.fabs(dat5[:,0]-2.1)<0.0001]),label='clvisc1.5')
#plt.plot(dat5[np.fabs(dat5[:,0]-2.0)<0.0001,3],(qtau[np.fabs(dat5[:,0]-2.0)<0.0001]),label='clvisc2.0')
#plt.plot(dat5[np.fabs(dat5[:,0]-5)<0.0001,3],(qtau[np.fabs(dat5[:,0]-10)<0.0001]),label='clvisc3.0')
#plt.plot(dat5[np.fabs(dat5[:,0]-10)<0.0001,3],u3[np.fabs(dat5[:,0]-10)<0.0001],label='clvisc')

#dat5[np.fabs(dat5[:,0]-1.0)<0.0001,0].shape
plt.legend()
# Out:
# 8.166691986843944e-05
# 6.093120464356616e-05

# %%
# plt.figure(figsize=(12,10))
# plt.plot(music1[:,0],music1[:,1],label = "MUSIC",linewidth=3)
# plt.plot(music2[:,0],music2[:,1],linewidth=3,)
# plt.plot(music5[:,0],music5[:,1],linewidth=3)
# plt.plot(music10[:,0],music10[:,1],linewidth=3)
# plt.plot(music20[:,0],music20[:,1],linewidth=3)

# plt.scatter(dat5[np.fabs(dat5[:,0]-1.0)<0.0001,3][0:-1:20],dat5[np.fabs(dat5[:,0]-1.0)<0.0001,4][0:-1:20],label='clvisc',s=100)
# plt.scatter(dat5[np.fabs(dat5[:,0]-2.0)<0.0001,3][0:-1:20],dat5[np.fabs(dat5[:,0]-2.0)<0.0001,4][0:-1:20],s=100)
# plt.scatter(dat5[np.fabs(dat5[:,0]-5.0)<0.0001,3][0:-1:20],dat5[np.fabs(dat5[:,0]-5.0)<0.0001,4][0:-1:20],s=100)
# plt.scatter(dat5[np.fabs(dat5[:,0]-10.0)<0.0001,3][0:-1:20],dat5[np.fabs(dat5[:,0]-10.0)<0.0001,4][0:-1:20],s=100)
# plt.scatter(dat5[np.fabs(dat5[:,0]-20.0)<0.0001,3][0:-1:20],dat5[np.fabs(dat5[:,0]-20.0)<0.0001,4][0:-1:20],s=100)
# #plt.yscale('log')

# plt.xlim(-6.5,6.5)
# plt.xlabel("$\eta$")
# plt.ylabel("$ed \ (GeV/fm^{3})$")
# plt.legend()
